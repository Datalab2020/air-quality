# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
df = pd.read_csv('E:\Indices_air.csv')

df.isna().sum()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-1ec0ac01b118> in <module>
#       5 import seaborn as sns
#       6 import datetime as dt
# ----> 7 df = pd.read_csv('E:\Indices_air.csv')
#       8
#       9 df.isna().sum()
#
# ...

# %%
df.date_ech = pd.to_datetime(df.date_ech, infer_datetime_format=True)

# %%
df
# Out:
#              X          Y   date_ech  valeur qualif   source type_zone  \
# 0     1.903984  47.903174 2019-01-02       3    Bon  Lig'Air      EPCI
# 1     0.682860  47.394438 2018-10-14       4    Bon  Lig'Air      EPCI
# 2     2.396232  47.079706 2019-01-02       3    Bon  Lig'Air      EPCI
# 3     1.490599  48.445544 2018-10-20       5  Moyen  Lig'Air      EPCI
# 4     1.696049  46.810434 2018-10-20       5  Moyen  Lig'Air      EPCI
# ...        ...        ...        ...     ...    ...      ...       ...
# 8091  1.490599  48.445544 2018-09-04       3    Bon  Lig'Air      EPCI
# 8092  1.696049  46.810434 2018-09-04       5  Moyen  Lig'Air      EPCI
# 8093  1.322670  47.590341 2018-09-04       5  Moyen  Lig'Air      EPCI
# 8094  1.359952  48.748753 2018-09-04       3    Bon  Lig'Air      EPCI
# 8095  2.736690  47.997953 2018-09-04       5  Moyen  Lig'Air      EPCI
#
#       code_zone     lib_zone  val_no2  val_so2  val_o3  val_pm10  val_pm25  \
# ...

# %%
df_Or = df.iloc[np.where(df['lib_zone'] == 'BLOIS')[0], :]

# %%
df_Or
# Out:
#             X          Y   date_ech  valeur qualif   source type_zone  \
# 5     1.32267  47.590341 2018-10-20       5  Moyen  Lig'Air      EPCI
# 8     1.32267  47.590341 2019-01-02       3    Bon  Lig'Air      EPCI
# 12    1.32267  47.590341 2020-05-27       5  Moyen  Lig'Air      EPCI
# 20    1.32267  47.590341 2018-11-07       3    Bon  Lig'Air      EPCI
# 28    1.32267  47.590341 2018-11-11       3    Bon  Lig'Air      EPCI
# ...       ...        ...        ...     ...    ...      ...       ...
# 8061  1.32267  47.590341 2018-10-01       3    Bon  Lig'Air      EPCI
# 8069  1.32267  47.590341 2018-09-01       5  Moyen  Lig'Air      EPCI
# 8077  1.32267  47.590341 2018-09-02       5  Moyen  Lig'Air      EPCI
# 8085  1.32267  47.590341 2018-09-03       5  Moyen  Lig'Air      EPCI
# 8093  1.32267  47.590341 2018-09-04       5  Moyen  Lig'Air      EPCI
#
#       code_zone lib_zone  val_no2  val_so2  val_o3  val_pm10  val_pm25  \
# ...

# %%
df_Or = df.iloc[np.where(df['year'] == '1')[0], :]

# %%
df['lib_zone'].unique()
# Out:
# array(['ORLEANS', 'TOURS', 'BOURGES', 'CHARTRES', 'CHATEAUROUX', 'BLOIS',
#        'DREUX', 'MONTARGIS'], dtype=object)

# %%
df_Or['mois'] = df_Or['date_ech'].dt.month
df_Or['annee'] = df_Or['date_ech'].dt.year
df_Or
dfpm = df_Or.groupby(by=['annee', 'mois']).mean()

dfpm.plot(y=['val_no2','val_so2','val_pm10','val_pm25'])
# Out:
# <ipython-input-19-f094b04c7a5b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Or['mois'] = df_Or['date_ech'].dt.month
# <ipython-input-19-f094b04c7a5b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Or['annee'] = df_Or['date_ech'].dt.year

# %%
dfpm
# Out:
#                   X          Y    valeur    code_zone   val_no2  val_so2  \
# annee mois
# 2018  1     1.32267  47.590341  3.225806  200030385.0  1.290323      1.0
#       2     1.32267  47.590341  3.750000  200030385.0  1.607143      1.0
#       3     1.32267  47.590341  3.935484  200030385.0  1.225806      1.0
#       4     1.32267  47.590341  4.133333  200030385.0  1.466667      1.0
#       5     1.32267  47.590341  4.645161  200030385.0  1.000000      1.0
#       6     1.32267  47.590341  4.066667  200030385.0  1.000000      1.0
#       7     1.32267  47.590341  4.870968  200030385.0  1.032258      1.0
#       8     1.32267  47.590341  4.129032  200030385.0  1.225806      1.0
#       9     1.32267  47.590341  4.233333  200030385.0  1.466667      1.0
#       10    1.32267  47.590341  3.741935  200030385.0  1.580645      1.0
#       11    1.32267  47.590341  3.000000  200030385.0  1.466667      1.0
#       12    1.32267  47.590341  3.258065  200030385.0  1.225806      1.0
# ...

# %%
for i in df['lib_zone'].unique() :
    df_Or = df.iloc[np.where(df['lib_zone'] == i)[0], :]
    df_Or['mois'] = df_Or['date_ech'].dt.month;
    df_Or['annee'] = df_Or['date_ech'].dt.year;
    dfpm = df_Or.groupby(by=['annee', 'mois']).mean()
    dfpm.plot(y=['val_no2','val_so2','val_pm10','val_o3','val_pm25'], figsize= (15,5))
    plt.title(i);
# Out:
# <ipython-input-34-73f83d5f4811>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Or['mois'] = df_Or['date_ech'].dt.month;
# <ipython-input-34-73f83d5f4811>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Or['annee'] = df_Or['date_ech'].dt.year;
# <ipython-input-34-73f83d5f4811>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# # L'impact du confinement ? / Faire des suppositions

# %%
dfpm
# Out:
#                    X          Y    valeur    code_zone   val_no2  val_so2  \
# annee mois
# 2018  1     1.903984  47.903174  3.032258  244500468.0  1.225806      1.0
#       2     1.903984  47.903174  3.607143  244500468.0  1.571429      1.0
#       3     1.903984  47.903174  3.870968  244500468.0  1.451613      1.0
#       4     1.903984  47.903174  4.166667  244500468.0  1.333333      1.0
#       5     1.903984  47.903174  4.548387  244500468.0  1.000000      1.0
#       6     1.903984  47.903174  3.900000  244500468.0  1.033333      1.0
#       7     1.903984  47.903174  5.193548  244500468.0  1.225806      1.0
#       8     1.903984  47.903174  4.161290  244500468.0  1.064516      1.0
#       9     1.903984  47.903174  4.200000  244500468.0  1.466667      1.0
#       10    1.903984  47.903174  3.741935  244500468.0  1.483871      1.0
#       11    1.903984  47.903174  2.966667  244500468.0  1.300000      1.0
# ...

# %%
sns.relplot(
    data=dfpm,
    y="val_no2",
    kind="line",height=10)

# %%
df['mois'] = df['date_ech'].dt.month

sns.relplot(
    data=df,
    x="date_ech", y="val_no2",
    hue="lib_zone", kind="line",height=10)
